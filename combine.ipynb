# %%
import pandas as pd

# %%
df1 = pd.read_csv("updated_labels.csv")
df2 = pd.read_csv("test_updated_labels.csv")

# Combine them (stack one below the other)
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save the combined data
combined_df.to_csv("combined_dataset.csv", index=False)
